# %%
import pandas as pd

# %%
df = pd.read_csv('./jobs.csv')
df.head(10)
# Out:
#    Unnamed: 0                                                  0  \
# 0           0                                                NaN
# 1           1    {'title': '4 Bed House with En Suite at Runda'}
# 2           2  {'title': '3 Bed House with En Suite in Rosslyn'}
# 3           3  {'title': '4 Bed Villa with En Suite in Laving...
# 4           4  {'title': '4 Bed House with En Suite at Eden V...
# 5           5  {'title': '4 Bed Townhouse with En Suite in Ru...
# 6           6      {'title': '4 Bed House with Garden at Runda'}
# 7           7    {'title': '4 Bed House with En Suite at Runda'}
# 8           8    {'title': '5 Bed House with En Suite in Karen'}
# 9           9  {'title': '4 Bed House with En Suite in Muthai...
#
#                                                    1  \
# 0                                                NaN
# 1  {'title': '4 Bed Townhouse with En Suite in La...
# 2    {'title': '1 Bed House with Garden at Loresho'}
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10 non-null     int64
#  1   0           9 non-null      object
#  2   1           9 non-null      object
#  3   2           9 non-null      object
#  4   3           9 non-null      object
#  5   4           9 non-null      object
#  6   5           9 non-null      object
#  7   6           9 non-null      object
#  8   7           9 non-null      object
#  9   8           9 non-null      object
#  10  9           9 non-null      object
#  11  10          9 non-null      object
#  12  11          9 non-null      object
#  13  12          9 non-null      object
#  14  13          9 non-null      object
#  15  14          9 non-null      object
#  16  15          1 non-null      object
#  17  16          1 non-null      object
# dtypes: int64(1), object(17)
# memory usage: 1.5+ KB
